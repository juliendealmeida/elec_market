# %%
# 3 agents: renewable, gas exit, coal exit

# %%
import numpy as np
from scipy.stats import norm
from scipy.optimize import linprog
import matplotlib
import matplotlib.pyplot as plt
import time
from cvxopt import solvers, matrix, sparse
from scipy.optimize import root_scalar
from scipy.sparse import bsr_matrix
from scipy.stats import gamma
from scipy.stats import beta

# %%
# interval
Smin=.1
Smax=.7
Cmin=0
Cmax = 120
tmin=0
tmax=30

# number for points
NS=21
NC = 21
Nt=61

# discretization
dS=1.*(Smax-Smin)/(NS-1)
dC = 1.*(Cmax-Cmin)/(NC-1)
dt=1.*(tmax-tmin)/(Nt-1)

# define grid in space
S = np.linspace(Smin,Smax,NS)
C = np.linspace(Cmin,Cmax,NC)
T = np.linspace(tmin,tmax,Nt)

# long-term average cost
theta_G = 37.94*0.88
theta_C = 37.94*0.88
theta_R = 0.4

# standard deviation
std_G = 12.53*0.88
std_C = 12.53*0.88
std_R = 0.075

# rate of mean reversion
kG=0.5
kC=0.5
kR = 0.5

# variability of the cost process 
delta_G = std_G*np.sqrt(2.*kG/theta_G)
delta_C = std_C*np.sqrt(2.*kC/theta_C)
delta_R = std_R*np.sqrt(2.*kR/(theta_R*(1-theta_R)-std_R*std_R))

rho=.08

epsilon = 0.5

# depreciation rate
gamma_G = np.log(2.)/15.
gamma_C = np.log(2.)/20.
gamma_R = np.log(2.)/12.5

# conversion of hourly revenue per MW into annual revenue per kW
convcoef = 24.*365.25/1000. 

# maximal price 
P=150.

K_R=1750. # per kW of installed capacity (who enter - fixing cost of owning the plant)
K_G = 0 # per kW of installed capacity (who exit - value recovered if the plant is sold)
K_C = 0 # per kW of installed capacity (who exit - value recovered if the plant is sold)

# fixed cost
k_G = 42. # per kW per year
k_C = 68. # per kW per year
k_R = 30. # per kW per year


# initial condition gas producers who exit
alpha_G = (theta_G/std_G)*(theta_G/std_G)
beta_G = theta_G/std_G/std_G
InitialOmega = 31.9*beta_G*gamma.pdf(beta_G*C,alpha_G)

# initial condition coal producers who exit
alpha_C = (theta_C/std_C)*(theta_C/std_C)
beta_C = theta_C/std_C/std_C
InitialMu = 43.*beta_C*gamma.pdf(beta_C*C,alpha_C)

# initial condition renewable producers
alpha_R = theta_R*(theta_R*(1.-theta_R)/std_R/std_R-1.)
beta_R = (1.-theta_R)*(theta_R*(1.-theta_R)/std_R/std_R-1.)
BarEta=114.7*beta.pdf(S,alpha_R,beta_R)
InitialEta=60.*beta.pdf(S,alpha_R,beta_R)

# demand
demand = np.array([33.68,33.68,33.68,33.68,33.11,33.11,33.11,33.11,32.68,32.68,32.68,32.68,
                   32.45,32.45,32.45,32.45,32.53,32.53,32.53,32.53,32.81,32.81,32.81,32.81,
                   33.19,33.19,33.19,33.19,33.56,33.56,33.56,33.56,
                   34.03,34.03,34.03,34.03,34.64,34.64,34.64,34.64,35.34,35.34,35.34,35.34,
                   36.02,36.02,36.02,36.02,36.78,36.78,36.78,36.78,37.29,37.29,37.29,37.29,
                   37.78,37.78,37.78,37.78,38.39,38.39,38.39,38.39,38.39,38.39,38.39,38.39,
                  38.39,38.39,38.39,38.39,38.39,38.39,38.39,38.39,38.39,38.39,38.39,38.39,38.39,
                  38.39,38.39,38.39,38.39,38.39,38.39,38.39,38.39,38.39,38.39,38.39,38.39,38.39,
                  38.39,38.39,38.39,38.39,38.39,38.39,38.39])

# Adjusting for seasonal cycle
sc = np.array([1.10352635, 0.93209028, 0.90656527, 1.05781809])
for i in range(25): demand[i*4:(i+1)*4] = demand[i*4:(i+1)*4]*sc
demand[100] = demand[100]*sc[0]

# peak / offpeak demand ratio
Dc = 1.2875630406414182

# peak hours
pcoef = 65./168
# off-peak hours
opcoef = 1.-pcoef

# peak demand
pdemand = demand*Dc/(pcoef*Dc+opcoef)
# off-peak demand
opdemand = demand/(pcoef*Dc+opcoef)

# fonction G in the definition of the reward function for exit
def G(x):
    return (epsilon/2+(x-epsilon))*(x>epsilon)+x*x/2/epsilon*(x>0)*(x<=epsilon)

def F(x):
    return (x-epsilon>0)+x/epsilon*(x>0)*(x<=epsilon)

# baseline supply
def F0(X):
    return 35.2*X/150.

# fonction g - payoff exit gas player
def g(x,p,t):
    return convcoef*G(p-x)-k_G - (rho+gamma_G)*K_G*np.exp(-gamma_G*t)

# fonction f - payoff entry renewable player
def f(x,p,t):
    return -convcoef*p*x+k_R + rho*K_R + gamma_R*K_R*np.exp(-(rho+gamma_R)*(tmax-t))

# fonction l - payoff exit coal player
def l(x,p,t):
    return convcoef*G(p-x)-k_C - (rho+gamma_C)*K_C*np.exp(-gamma_C*t)

# residual demand
def computeR(eta,dem):
    R = np.zeros(Nt)
    maxdem = sum(S[:-1]*BarEta[0:NS-1])*dS
    for i in range(Nt):
        R[i]=dem[i]+sum(S[:-1]*eta[i*NS:(i+1)*NS-1])*dS-maxdem
        R[i] = R[i]*(R[i]>0)
    return R

# function which computes the price for given densities at a given time t
def price(t,R,O,M):
    if R[t]==0: return 0
    def func(x):
        return sum(F(x-C)*(O[t*NC:(t+1)*NC]+M[t*NC:(t+1)*NC]))*dC-R[t]+F0(x)
    if func(P)<=0: return P
    return root_scalar(func,bracket=(0.,P),x0 = P/2).root  

################################################################################################################
# find the maximum on omega at a given iteration
################################################################################################################
def OptExit_G(Omega,Eta,Mu):
    # residual demand for peak and off-peak demand
    Rp = computeR(Eta,pdemand)
    Rop = computeR(Eta,opdemand)
    
    # price for peak and off-peak demand
    Prp = np.zeros(Nt)
    Prop = np.zeros(Nt)
    for j in range(Nt):
        Prp[j] = price(j,Rp,Omega,Mu)
        Prop[j] = price(j,Rop,Omega,Mu)

    # constraints    
    H=np.zeros(Nt*NC)
    for i in range(Nt):
        H[i*NC:(i+1)*NC]=dC*dt*np.exp(-rho*(T[i]))*(pcoef*g(C,Prp[i],T[i])+opcoef*g(C,Prop[i],T[i]))
    
    # neumann conditions
    A=np.zeros((NC,NC))
    V=1.+delta_G*delta_G*C*dt/(dC*dC)
    V1 =-delta_G*delta_G*C[1:]*dt/(2*dC*dC)+kG*(theta_G-C[1:])*dt/(2*dC)
    V2=-delta_G*delta_G*C[:-1]*dt/(2*dC*dC)-kG*(theta_G-C[:-1])*dt/(2*dC)
    A.flat[::NC+1] = V
    A.flat[1::NC+1] = V1
    A.flat[NC::NC+1] = V2

    A_ub = np.zeros(((Nt-1)*NC,(Nt-1)*NC))
    for i in range(Nt-1):
        A_ub[((i)*NC):((i+1)*NC), ((i)*NC):((i+1)*NC)] = A
    for i in range(Nt-2):
        A_ub[((i+1)*NC):((i+2)*NC), ((i)*NC):((i+1)*NC)] = -np.diag(np.ones(NC))
    b_ub=np.zeros((Nt-1)*NC)
    b_ub[:NC] = InitialOmega

    t0 = time.time()
    res = linprog(-H[NC:],bsr_matrix(A_ub),b_ub,options={"sparse":True})
    if(res.status): print('OpExit: '+res.message)

    M1 = res.x
    val = np.dot(H[NC:],Omega[NC:])
    ob_func = np.dot(H[NC:],M1)- val
    t1 = time.time()

    return ob_func, val, M1

################################################################################################################
# find the maximum on mu at a given iteration
################################################################################################################
def OptExit_C(Omega,Eta,Mu):
    # residual demand for peak and off-peak demand
    Rp = computeR(Eta,pdemand)
    Rop = computeR(Eta,opdemand)
    
    # price for peak and off-peak demand
    Prp = np.zeros(Nt)
    Prop = np.zeros(Nt)
    for j in range(Nt):
        Prp[j] = price(j,Rp,Omega,Mu)
        Prop[j] = price(j,Rop,Omega,Mu)

    # constraints    
    H=np.zeros(Nt*NC)
    for i in range(Nt):
        H[i*NC:(i+1)*NC]=dC*dt*np.exp(-rho*(T[i]))*(pcoef*l(C,Prp[i],T[i])+opcoef*l(C,Prop[i],T[i]))
    
    # neumann conditions
    A=np.zeros((NC,NC))
    V=1.+delta_C*delta_C*C*dt/(dC*dC)
    V1 =-delta_C*delta_C*C[1:]*dt/(2*dC*dC)+kC*(theta_C-C[1:])*dt/(2*dC)
    V2=-delta_C*delta_C*C[:-1]*dt/(2*dC*dC)-kC*(theta_C-C[:-1])*dt/(2*dC)
    A.flat[::NC+1] = V
    A.flat[1::NC+1] = V1
    A.flat[NC::NC+1] = V2

    A_ub = np.zeros(((Nt-1)*NC,(Nt-1)*NC))
    for i in range(Nt-1):
        A_ub[((i)*NC):((i+1)*NC), ((i)*NC):((i+1)*NC)] = A
    for i in range(Nt-2):
        A_ub[((i+1)*NC):((i+2)*NC), ((i)*NC):((i+1)*NC)] = -np.diag(np.ones(NC))
    b_ub=np.zeros((Nt-1)*NC)
    b_ub[:NC] = InitialMu

    t0 = time.time()
    res = linprog(-H[NC:],bsr_matrix(A_ub),b_ub,options={"sparse":True})
    if(res.status): print('OpExit: '+res.message)

    M1 = res.x
    val = np.dot(H[NC:],Mu[NC:])
    ob_func = np.dot(H[NC:],M1)- val
    t1 = time.time()

    return ob_func, val, M1

################################################################################################################
# find the maximum on eta at a given iteration
################################################################################################################
def OptEntry_R(Omega,Eta,Mu):
    # residual demand for peak and off-peak demand
    Rp = computeR(Eta,pdemand)
    Rop = computeR(Eta,opdemand)
    
    # price for peak and off-peak demand
    Prp = np.zeros(Nt)
    Prop = np.zeros(Nt)
    for j in range(Nt):
        Prp[j] = price(j,Rp,Omega,Mu)
        Prop[j] = price(j,Rop,Omega,Mu)

    # constraints
    barH=np.zeros(Nt*NS)
    for i in range(Nt):
        barH[i*NS:(i+1)*NS]=dS*dt*np.exp(-rho*T[i])*(pcoef*f(S,Prp[i],T[i])+opcoef*f(S,Prop[i],T[i]))        
    # neumann conditions
    barA=np.zeros((NS,NS))
    barV=1.+delta_R*delta_R*S*(1-S)*dt/(dS*dS)
    barV1 = -delta_R*delta_R*S[1:]*(1.-S[1:])*dt/(2*dS*dS)+kR*(theta_R-S[1:])*dt/(2*dS)
    barV2 = -delta_R*delta_R*S[:-1]*(1.-S[:-1])*dt/(2*dS*dS)-kR*(theta_R-S[:-1])*dt/(2*dS)
    barA.flat[::NS+1] = barV
    barA.flat[1::NS+1] = barV1
    barA.flat[NS::NS+1] = barV2

    A_ub = np.zeros(((Nt-1)*NS,(Nt-1)*NS))
    for i in range(Nt-1):
        A_ub[((i)*NS):((i+1)*NS), ((i)*NS):((i+1)*NS)] = barA
    for i in range(Nt-2):
        A_ub[((i+1)*NS):((i+2)*NS), ((i)*NS):((i+1)*NS)] = -np.diag(np.ones(NS))
    b_ub=np.zeros((Nt-1)*NS)
    b_ub[:NS] = InitialEta

    t0 = time.time()
    res = linprog(-barH[NS:],bsr_matrix(A_ub),b_ub,options={"sparse":True})
    if(res.status): print('OpEntry: '+res.message)

    M1 = res.x
    val = np.dot(barH[NS:],Eta[NS:])
    ob_func = np.dot(barH[NS:],M1)- val
    t1 = time.time()

    return ob_func, val, M1

# %%
Niter=50 # total number of iterations
tol = 1. # convergence achieved if objective function less than tol

# initialisation of omega (exit for gas)
Omega=np.zeros(Nt*NC)
Omega[:NC]=InitialOmega

# initialisation of mu (exit for gas)
Mu=np.zeros(Nt*NC)
Mu[:NC]=InitialMu

# initialisation of eta
Eta=np.zeros(Nt*NS)
Eta[:NS] = InitialEta

# peak and peak-off price value (historical)
prphist = np.zeros((Nt,Niter))
prophist = np.zeros((Nt,Niter))

# renewable produice energy
renpen = np.zeros((Nt,Niter))

# conventional capacity
conhist = np.zeros((Nt,Niter))

# electricity produice
penhist = np.zeros((Nt,Niter))

# stock residual peak and off-peak demand value (historical)
RRp = np.zeros((Nt,Niter))
RRop = np.zeros((Nt,Niter))
Pr = np.zeros(Nt)

out1 = "Initial Objectives: Renewable: {:.2f}; Conventional gas exit:  {:.2f}; Conventional coal exit:  {:.2f}; Total: {:.2f}"
out2 = "Weight: {:.4f}; Renewable: {:.2f}; Conventional gas exit:  {:.2f}; Conventional coal exit:  {:.2f}; Total: {:.2f}"

# save objectives
save_ob_G = np.zeros(Niter)
save_ob_C = np.zeros(Niter)
save_ob_R = np.zeros(Niter)

# initialize
ob_G, val_G, Omega1=OptExit_G(Omega,Eta,Mu)
ob_C, val_C, Mu1=OptExit_C(Omega,Eta,Mu)
ob_R, val_R, Eta1=OptEntry_R(Omega,Eta,Mu)
print(out1.format(ob_R,ob_G,ob_C,ob_C+ob_G+ob_R))

for i in range(Niter):  

    save_ob_G[i] = ob_G
    save_ob_C[i] = ob_C
    save_ob_R[i] = ob_R

    if ob_R+ob_G+ob_C < tol:
        print('Convergence achieved')
        Niter = i
        break

    print('Iteration ',i)   

    # store intermediate values
    Rp = computeR(Eta,pdemand)
    Rop = computeR(Eta,opdemand)
    
    Prp = np.zeros(Nt)
    Prop = np.zeros(Nt)
    for j in range(Nt):
        Prp[j] = price(j,Rp,Omega,Mu)
        Prop[j] = price(j,Rop,Omega,Mu)
        prphist[j,i] = Prp[j]
        prophist[j,i] = Prop[j]
            
    newEta = np.reshape(Eta,(Nt,NS))
    newOm = np.reshape(Omega,(Nt,NC))
    newMu = np.reshape(Mu,(Nt,NC))

    penhist[:,i] = np.sum(newEta,axis=1)*dS
    conhist[:,i] = np.sum(newOm,axis=1)*dC
    renpen[:,i] = np.sum(newEta*S,axis=1)*dS

    # stock residual peak and off-peak demand value (historical)
    RRp[:,i] = Rp
    RRop[:,i] = Rop

    # step size
    weight = 1./(i+1)

    # upgrade the mesures
    Omega[NC:] = (1.-weight)*Omega[NC:]+weight*Omega1
    Mu[NC:] = (1.-weight)*Mu[NC:]+weight*Mu1
    Eta[NS:] = (1.-weight)*Eta[NS:]+weight*Eta1

    # search the solution
    ob_G, val_G, Omega1=OptExit_G(Omega,Eta,Mu)
    ob_C, val_C, Mu1=OptExit_C(Omega,Eta,Mu)
    ob_R, val_R, Eta1=OptEntry_R(Omega,Eta,Mu)

    # advancement
    print(out2.format(weight,ob_R,ob_G,ob_C,ob_C+ob_G+ob_R))
# Out:
# Initial Objectives: Renewable: 120770.82; Conventional gas exit:  -0.00; Conventional coal exit:  -0.00; Total: 120770.82
# Iteration  0
# Weight: 1.0000; Renewable: 1188.63; Conventional gas exit:  32165.58; Conventional coal exit:  33437.77; Total: 66791.98
# Iteration  1
# Weight: 0.5000; Renewable: 9199.92; Conventional gas exit:  5203.98; Conventional coal exit:  11973.66; Total: 26377.57
# Iteration  2
# Weight: 0.3333; Renewable: 5214.57; Conventional gas exit:  3007.46; Conventional coal exit:  7349.54; Total: 15571.58
# Iteration  3
# Weight: 0.2500; Renewable: 3438.32; Conventional gas exit:  1886.41; Conventional coal exit:  5003.29; Total: 10328.02
# Iteration  4
# Weight: 0.2000; Renewable: 2445.82; Conventional gas exit:  1138.08; Conventional coal exit:  3476.11; Total: 7060.01
# Iteration  5
# Weight: 0.1667; Renewable: 1829.15; Conventional gas exit:  657.59; Conventional coal exit:  2441.83; Total: 4928.57
# Iteration  6
# Weight: 0.1429; Renewable: 1412.15; Conventional gas exit:  355.31; Conventional coal exit:  1721.73; Total: 3489.19
# Iteration  7
# Weight: 0.1250; Renewable: 1125.41; Conventional gas exit:  435.83; Conventional coal exit:  1233.47; Total: 2794.71
# Iteration  8
# Weight: 0.1111; Renewable: 996.09; Conventional gas exit:  263.42; Conventional coal exit:  1180.90; Total: 2440.41
# Iteration  9
# Weight: 0.1000; Renewable: 862.68; Conventional gas exit:  286.75; Conventional coal exit:  998.62; Total: 2148.05
# Iteration  10
# Weight: 0.0909; Renewable: 785.77; Conventional gas exit:  211.44; Conventional coal exit:  958.70; Total: 1955.91
# Iteration  11
# Weight: 0.0833; Renewable: 704.36; Conventional gas exit:  216.28; Conventional coal exit:  849.09; Total: 1769.74
# Iteration  12
# Weight: 0.0769; Renewable: 641.38; Conventional gas exit:  208.14; Conventional coal exit:  774.11; Total: 1623.63
# Iteration  13
# Weight: 0.0714; Renewable: 588.43; Conventional gas exit:  200.46; Conventional coal exit:  711.44; Total: 1500.33
# Iteration  14
# Weight: 0.0667; Renewable: 544.34; Conventional gas exit:  193.08; Conventional coal exit:  660.57; Total: 1397.99
# Iteration  15
# Weight: 0.0625; Renewable: 517.29; Conventional gas exit:  142.08; Conventional coal exit:  661.01; Total: 1320.38
# Iteration  16
# Weight: 0.0588; Renewable: 480.92; Conventional gas exit:  141.51; Conventional coal exit:  610.04; Total: 1232.46
# Iteration  17
# Weight: 0.0556; Renewable: 450.65; Conventional gas exit:  138.03; Conventional coal exit:  570.97; Total: 1159.66
# Iteration  18
# Weight: 0.0526; Renewable: 423.82; Conventional gas exit:  134.66; Conventional coal exit:  536.34; Total: 1094.82
# Iteration  19
# Weight: 0.0500; Renewable: 399.87; Conventional gas exit:  131.81; Conventional coal exit:  505.48; Total: 1037.16
# Iteration  20
# Weight: 0.0476; Renewable: 378.94; Conventional gas exit:  127.62; Conventional coal exit:  479.47; Total: 986.03
# Iteration  21
# Weight: 0.0455; Renewable: 360.35; Conventional gas exit:  123.03; Conventional coal exit:  456.58; Total: 939.95
# Iteration  22
# Weight: 0.0435; Renewable: 343.47; Conventional gas exit:  118.64; Conventional coal exit:  435.84; Total: 897.96
# Iteration  23
# Weight: 0.0417; Renewable: 328.03; Conventional gas exit:  114.64; Conventional coal exit:  416.82; Total: 859.50
# Iteration  24
# Weight: 0.0400; Renewable: 313.99; Conventional gas exit:  110.84; Conventional coal exit:  399.44; Total: 824.27
# Iteration  25
# Weight: 0.0385; Renewable: 301.05; Conventional gas exit:  107.34; Conventional coal exit:  383.38; Total: 791.77
# Iteration  26
# Weight: 0.0370; Renewable: 289.13; Conventional gas exit:  104.09; Conventional coal exit:  368.52; Total: 761.75
# Iteration  27
# Weight: 0.0357; Renewable: 278.13; Conventional gas exit:  101.01; Conventional coal exit:  354.82; Total: 733.95
# Iteration  28
# Weight: 0.0345; Renewable: 268.21; Conventional gas exit:  96.86; Conventional coal exit:  343.14; Total: 708.21
# Iteration  29
# Weight: 0.0333; Renewable: 258.68; Conventional gas exit:  94.28; Conventional coal exit:  331.16; Total: 684.12
# Iteration  30
# Weight: 0.0323; Renewable: 250.09; Conventional gas exit:  90.61; Conventional coal exit:  320.99; Total: 661.70
# Iteration  31
# Weight: 0.0312; Renewable: 241.82; Conventional gas exit:  88.21; Conventional coal exit:  310.56; Total: 640.59
# Iteration  32
# Weight: 0.0303; Renewable: 234.28; Conventional gas exit:  84.96; Conventional coal exit:  301.60; Total: 620.83
# Iteration  33
# Weight: 0.0294; Renewable: 227.02; Conventional gas exit:  82.86; Conventional coal exit:  292.36; Total: 602.24
# Iteration  34
# Weight: 0.0286; Renewable: 220.35; Conventional gas exit:  79.97; Conventional coal exit:  284.40; Total: 584.72
# Iteration  35
# Weight: 0.0278; Renewable: 213.94; Conventional gas exit:  78.11; Conventional coal exit:  276.19; Total: 568.24
# Iteration  36
# Weight: 0.0270; Renewable: 208.04; Conventional gas exit:  75.55; Conventional coal exit:  269.05; Total: 552.64
# Iteration  37
# Weight: 0.0263; Renewable: 202.30; Conventional gas exit:  73.89; Conventional coal exit:  261.69; Total: 537.89
# Iteration  38
# Weight: 0.0256; Renewable: 197.02; Conventional gas exit:  71.56; Conventional coal exit:  255.31; Total: 523.89
# Iteration  39
# Weight: 0.0250; Renewable: 191.85; Conventional gas exit:  70.07; Conventional coal exit:  248.67; Total: 510.59
# Iteration  40
# Weight: 0.0244; Renewable: 187.10; Conventional gas exit:  67.99; Conventional coal exit:  242.87; Total: 497.96
# Iteration  41
# Weight: 0.0238; Renewable: 182.45; Conventional gas exit:  66.62; Conventional coal exit:  236.89; Total: 485.95
# Iteration  42
# Weight: 0.0233; Renewable: 178.14; Conventional gas exit:  64.71; Conventional coal exit:  231.64; Total: 474.49
# Iteration  43
# Weight: 0.0227; Renewable: 173.89; Conventional gas exit:  63.50; Conventional coal exit:  226.17; Total: 463.56
# Iteration  44
# Weight: 0.0222; Renewable: 170.00; Conventional gas exit:  61.76; Conventional coal exit:  221.38; Total: 453.13
# Iteration  45
# Weight: 0.0217; Renewable: 166.15; Conventional gas exit:  60.61; Conventional coal exit:  216.41; Total: 443.17
# Iteration  46
# Weight: 0.0213; Renewable: 162.57; Conventional gas exit:  59.03; Conventional coal exit:  212.02; Total: 433.62
# Iteration  47
# Weight: 0.0208; Renewable: 159.03; Conventional gas exit:  57.99; Conventional coal exit:  207.44; Total: 424.46
# Iteration  48
# Weight: 0.0204; Renewable: 155.74; Conventional gas exit:  56.53; Conventional coal exit:  203.42; Total: 415.69
# Iteration  49
# Weight: 0.0200; Renewable: 152.48; Conventional gas exit:  55.57; Conventional coal exit:  199.20; Total: 407.24

# %%
# Algorithm convergence illustration
logIter = np.log(range(1,Niter,1))

plt.figure()
plt.plot(logIter, np.log(save_ob_R[1:]), label = "Renewable enter")
plt.plot(logIter, np.log(save_ob_G[1:]), label = "Convention gas exit")
plt.plot(logIter, np.log(save_ob_C[1:]), label = "Convention coal exit")
plt.title("Algorithm convergence")
plt.xlabel('log(iterations)')
plt.ylabel('log(gain increase)')
plt.legend()
plt.show()

# %%
# Electricity demand projections, GW
plt.figure()
plt.plot(2018+T[:60],opdemand[:60],label='Total off-peak demand')
plt.plot(2018+T[:60],pdemand[:60],label='Total peak demand')
plt.title('Electricity demand projections, GW')
plt.legend()
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D # This import has side effects required for the kwarg projection='3d' in the call to fig.add_subplot

fig = plt.figure(figsize=(20,10))

newOm = np.reshape(Omega,(Nt,NC))
ax = fig.add_subplot(131, projection='3d')
XX, YY = np.meshgrid(C, T)
ax.plot_wireframe(XX, YY, newOm)
plt.title('Conventional gas exit')

newMu = np.reshape(Mu,(Nt,NC))
ax2 = fig.add_subplot(132, projection='3d')
XX, YY = np.meshgrid(C, T)
ax2.plot_wireframe(XX, YY, newMu)
plt.title('Conventional coal exit')

newEta = np.reshape(Eta,(Nt,NS))
XX, YY = np.meshgrid(S, T)
ax3 = fig.add_subplot(133, projection='3d')
ax3.plot_wireframe(XX, YY, newEta)
plt.title('Renewable')
# Out:
# Text(0.5, 0.92, 'Renewable')

# %%
plt.figure(figsize=(13,5))

plt.subplot(1,3,1)
plt.plot(Omega)
plt.title('Conventional gas exit')

plt.subplot(1,3,2)
plt.plot(Mu)
plt.title('Conventional coal exit')

plt.subplot(1,3,3)
plt.plot(Eta)
plt.title('Renewable')
# Out:
# Text(0.5, 1.0, 'Renewable')

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,3,1)
XX, YY = np.meshgrid(C, T)
plt.contourf(YY, XX, newOm)
plt.title('Conventional gas exit')

plt.subplot(1,3,2)
XX, YY = np.meshgrid(C, T)
plt.contourf(YY, XX, newMu)
plt.title('Conventional coal exit')

plt.subplot(1,3,3)
XX, YY = np.meshgrid(S, T)
plt.contourf(YY, XX, newEta)
plt.title('Renewable')
# Out:
# Text(0.5, 1.0, 'Renewable')

# %%
plt.figure(figsize=(14,10))

plt.subplot('231')
plt.plot(2018+T,RRp[:,Niter-1],label='Residual peak demand')
plt.plot(2018+T[:60],pdemand[:60],label='Total peak demand')
plt.plot(2018+T,RRop[:,Niter-1],label='Residual off-peak demand')
plt.plot(2018+T[:60],opdemand[:60],label='Total off-peak demand')
plt.title('Residual and total demand, GW')
plt.legend(loc=2)

plt.subplot('232')
plt.plot(2018+T,prphist[:,Niter-1],label='Peak price')
plt.plot(2018+T,prophist[:,Niter-1],label='Off-peak price')
plt.legend(loc=2)
plt.title('Price, GBP/MWh')

plt.subplot('233')
renhist = np.ones(penhist.shape)*np.sum(BarEta)*dS-penhist
plt.plot(2018+T,renhist[:,Niter-1]+conhist[:,Niter-1],label='Total')
plt.plot(2018+T,renhist[:,Niter-1],label='Renewable')
plt.plot(2018+T,conhist[:,Niter-1],label='Conventional')
plt.legend(loc=2)
plt.title('Installed capacity, GW')

plt.subplot('234')
plt.plot(2018+T,np.sum(BarEta*S)*dS-renpen[:,Niter-1])
plt.title('Renewable production, GW')

#plt.savefig('industry_dynamics_peak_offpeak_baseline.pdf',format='pdf')

plt.subplot('235')
plt.plot(T,conhist[:,-1])
plt.title('Conventional installed capacity')
# Out:
# <ipython-input-36-d026e0ca9f83>:3: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot('231')
# <ipython-input-36-d026e0ca9f83>:11: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot('232')
# <ipython-input-36-d026e0ca9f83>:17: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot('233')
# <ipython-input-36-d026e0ca9f83>:25: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot('234')
# <ipython-input-36-d026e0ca9f83>:31: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot('235')
# Text(0.5, 1.0, 'Conventional installed capacity')
