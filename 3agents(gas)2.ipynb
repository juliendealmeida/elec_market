# %%
# 3 agents: renewable, gas enter, gas exit 
# without computeM in the price

# %%
import numpy as np
from scipy.stats import norm
from scipy.optimize import linprog
import matplotlib
import matplotlib.pyplot as plt
import time
from cvxopt import solvers, matrix, sparse
from scipy.optimize import root_scalar
from scipy.sparse import bsr_matrix
from scipy.stats import gamma
from scipy.stats import beta

# %%
# interval
Smin=.1
Smax=.7
Cmin=0
Cmax = 120
tmin=0
tmax=30

# number for points
NS=21
NC = 21
Nt=61

# discretization
dS=1.*(Smax-Smin)/(NS-1)
dC = 1.*(Cmax-Cmin)/(NC-1)
dt=1.*(tmax-tmin)/(Nt-1)

# define grid in space
S = np.linspace(Smin,Smax,NS)
C = np.linspace(Cmin,Cmax,NC)
T = np.linspace(tmin,tmax,Nt)

# long-term average cost
theta_G = 37.94*0.88
theta_R = 0.4

# standard deviation
std_G = 12.53*0.88
std_R = 0.075

# rate of mean reversion
kG=0.5
kR = 0.5

# variability of the cost process 
delta_G = std_G*np.sqrt(2.*kG/theta_G)
delta_R = std_R*np.sqrt(2.*kR/(theta_R*(1-theta_R)-std_R*std_R))

rho=.08

epsilon = 0.5

# depreciation rate
gamma_G = np.log(2.)/15.
gamma_R = np.log(2.)/12.5

# conversion of hourly revenue per MW into annual revenue per kW
convcoef = 24.*365.25/1000. 

# maximal price 
P=150.

K_R = 1750. # per kW of installed capacity (who enter - fixing cost of owning the plant)
K_G_exit = 0 # per kW of installed capacity (who exit - value recovered if the plant is sold)
K_G_enter = 1450 # per kW of installed capacity (who enter - fixing cost of owning the plant)

# fixed cost
k_G = 42. # per kW per year
k_R = 30. # per kW per year


# initial condition gas producers who exit
alpha_G = (theta_G/std_G)*(theta_G/std_G)
beta_G = theta_G/std_G/std_G
InitialOmega = 31.9*beta_G*gamma.pdf(beta_G*C,alpha_G)
# initial condition gas producers who enter
InitialLambda = 36.*beta_G*gamma.pdf(beta_G*C,alpha_G)
BarLambda = 67.9*beta_G*gamma.pdf(beta_G*C,alpha_G)

# initial condition renewable producers
alpha_R = theta_R*(theta_R*(1.-theta_R)/std_R/std_R-1.)
beta_R = (1.-theta_R)*(theta_R*(1.-theta_R)/std_R/std_R-1.)
BarEta=114.7*beta.pdf(S,alpha_R,beta_R)
InitialEta=60.*beta.pdf(S,alpha_R,beta_R)

# demand
demand = np.array([33.68,33.68,33.68,33.68,33.11,33.11,33.11,33.11,32.68,32.68,32.68,32.68,
                   32.45,32.45,32.45,32.45,32.53,32.53,32.53,32.53,32.81,32.81,32.81,32.81,
                   33.19,33.19,33.19,33.19,33.56,33.56,33.56,33.56,
                   34.03,34.03,34.03,34.03,34.64,34.64,34.64,34.64,35.34,35.34,35.34,35.34,
                   36.02,36.02,36.02,36.02,36.78,36.78,36.78,36.78,37.29,37.29,37.29,37.29,
                   37.78,37.78,37.78,37.78,38.39,38.39,38.39,38.39,38.39,38.39,38.39,38.39,
                  38.39,38.39,38.39,38.39,38.39,38.39,38.39,38.39,38.39,38.39,38.39,38.39,38.39,
                  38.39,38.39,38.39,38.39,38.39,38.39,38.39,38.39,38.39,38.39,38.39,38.39,38.39,
                  38.39,38.39,38.39,38.39,38.39,38.39,38.39])

# Adjusting for seasonal cycle
sc = np.array([1.10352635, 0.93209028, 0.90656527, 1.05781809])
for i in range(25): demand[i*4:(i+1)*4] = demand[i*4:(i+1)*4]*sc
demand[100] = demand[100]*sc[0]

# peak / offpeak demand ratio
Dc = 1.2875630406414182

# peak hours
pcoef = 65./168
# off-peak hours
opcoef = 1.-pcoef

# peak demand
pdemand = demand*Dc/(pcoef*Dc+opcoef)
# off-peak demand
opdemand = demand/(pcoef*Dc+opcoef)

# fonction G in the definition of the reward function for exit
def G(x):
    return (epsilon/2+(x-epsilon))*(x>epsilon)+x*x/2/epsilon*(x>0)*(x<=epsilon)

def F(x):
    return (x-epsilon>0)+x/epsilon*(x>0)*(x<=epsilon)

# baseline supply
def F0(X):
    return 35.2*X/150.

# fonction g - payoff exit gas player
def g(x,p,t):
    return convcoef*G(p-x)-k_G - (rho+gamma_G)*K_G_exit*np.exp(-gamma_G*t)

# function h - payoff entry gas player
def h(x,p,t):
    return -convcoef*G(p-x) + k_G + rho*K_G_enter + gamma_G*K_G_enter*np.exp(-(rho+gamma_G)*(tmax-t))

# fonction f - payoff entry renewable player
def f(x,p,t):
    return -convcoef*p*x+k_R + rho*K_R + gamma_R*K_R*np.exp(-(rho+gamma_R)*(tmax-t))

# residual demand
def computeR(eta,dem):
    R = np.zeros(Nt)
    maxdem = sum(S[:-1]*BarEta[0:NS-1])*dS
    for i in range(Nt):
        R[i]=dem[i]+sum(S[:-1]*eta[i*NS:(i+1)*NS-1])*dS-maxdem
        R[i] = R[i]*(R[i]>0)
    return R

# total supply by the conventional gas producers at prive level p
def computeM(l, p):
    M = np.zeros(Nt)
    maxdem = sum(F(p-C[:-1])*BarLambda[0:NC-1])*dC
    for i in range(Nt):
        M[i] = maxdem - sum(F(p-C[:-1])*l[i*NC:(i+1)*NC-1])*dC
    return M  

# function which computes the price for given densities at a given time t
def price(t,R,M,L):
    if R[t]==0: return 0
    def func(x):
        return sum(F(x-C)*M[t*NC:(t+1)*NC])*dC-R[t]+F0(x)
    if func(P)<=0: return P
    return root_scalar(func,bracket=(0.,P),x0 = P/2).root   

################################################################################################################
# find the maximum on omega at a given iteration
################################################################################################################
def OptExit_G(Omega,Eta,Lambda):
    # residual demand for peak and off-peak demand
    Rp = computeR(Eta,pdemand)
    Rop = computeR(Eta,opdemand)
    
    # price for peak and off-peak demand
    Prp = np.zeros(Nt)
    Prop = np.zeros(Nt)
    for j in range(Nt):
        Prp[j] = price(j,Rp,Omega,Lambda)
        Prop[j] = price(j,Rop,Omega,Lambda)

    # constraints    
    H=np.zeros(Nt*NC)
    for i in range(Nt):
        H[i*NC:(i+1)*NC]=dC*dt*np.exp(-rho*(T[i]))*(pcoef*g(C,Prp[i],T[i])+opcoef*g(C,Prop[i],T[i]))
    
    # neumann conditions
    A=np.zeros((NC,NC))
    V=1.+delta_G*delta_G*C*dt/(dC*dC)
    V1 =-delta_G*delta_G*C[1:]*dt/(2*dC*dC)+kG*(theta_G-C[1:])*dt/(2*dC)
    V2=-delta_G*delta_G*C[:-1]*dt/(2*dC*dC)-kG*(theta_G-C[:-1])*dt/(2*dC)
    A.flat[::NC+1] = V
    A.flat[1::NC+1] = V1
    A.flat[NC::NC+1] = V2

    A_ub = np.zeros(((Nt-1)*NC,(Nt-1)*NC))
    for i in range(Nt-1):
        A_ub[((i)*NC):((i+1)*NC), ((i)*NC):((i+1)*NC)] = A
    for i in range(Nt-2):
        A_ub[((i+1)*NC):((i+2)*NC), ((i)*NC):((i+1)*NC)] = -np.diag(np.ones(NC))
    b_ub=np.zeros((Nt-1)*NC)
    b_ub[:NC] = InitialOmega

    t0 = time.time()
    res = linprog(-H[NC:],bsr_matrix(A_ub),b_ub,options={"sparse":True})
    if(res.status): print('OpExit: '+res.message)

    M1 = res.x
    val = np.dot(H[NC:],Omega[NC:])
    ob_func = np.dot(H[NC:],M1)- val
    t1 = time.time()

    return ob_func, val, M1

################################################################################################################
# find the maximum on lambda at a given iteration
################################################################################################################
def OptEntry_G(Omega,Eta,Lambda):
    # residual demand for peak and off-peak demand
    Rp = computeR(Eta,pdemand)
    Rop = computeR(Eta,opdemand)
    
    # price for peak and off-peak demand
    Prp = np.zeros(Nt)
    Prop = np.zeros(Nt)
    for j in range(Nt):
        Prp[j] = price(j,Rp,Omega,Lambda)
        Prop[j] = price(j,Rop,Omega,Lambda)

    # constraints    
    H=np.zeros(Nt*NC)
    for i in range(Nt):
        H[i*NC:(i+1)*NC]=dC*dt*np.exp(-rho*(T[i]))*(pcoef*h(C,Prp[i],T[i])+opcoef*h(C,Prop[i],T[i]))
    
    # neumann conditions
    A=np.zeros((NC,NC))
    V=1.+delta_G*delta_G*C*dt/(dC*dC)
    V1 =-delta_G*delta_G*C[1:]*dt/(2*dC*dC)+kG*(theta_G-C[1:])*dt/(2*dC)
    V2=-delta_G*delta_G*C[:-1]*dt/(2*dC*dC)-kG*(theta_G-C[:-1])*dt/(2*dC)
    A.flat[::NC+1] = V
    A.flat[1::NC+1] = V1
    A.flat[NC::NC+1] = V2

    A_ub = np.zeros(((Nt-1)*NC,(Nt-1)*NC))
    for i in range(Nt-1):
        A_ub[((i)*NC):((i+1)*NC), ((i)*NC):((i+1)*NC)] = A
    for i in range(Nt-2):
        A_ub[((i+1)*NC):((i+2)*NC), ((i)*NC):((i+1)*NC)] = -np.diag(np.ones(NC))
    b_ub=np.zeros((Nt-1)*NC)
    b_ub[:NC] = InitialLambda
    
    t0 = time.time()
    res = linprog(-H[NC:],bsr_matrix(A_ub),b_ub,options={"sparse":True})
    if(res.status): print('OpExit: '+res.message)

    M1 = res.x
    val = np.dot(H[NC:],Lambda[NC:])
    ob_func = np.dot(H[NC:],M1)- val
    t1 = time.time()

    return ob_func, val, M1

################################################################################################################
# find the maximum on eta at a given iteration
################################################################################################################
def OptEntry_R(Omega,Eta,Lambda):
    # residual demand for peak and off-peak demand
    Rp = computeR(Eta,pdemand)
    Rop = computeR(Eta,opdemand)
    
    # price for peak and off-peak demand
    Prp = np.zeros(Nt)
    Prop = np.zeros(Nt)
    for j in range(Nt):
        Prp[j] = price(j,Rp,Omega,Lambda)
        Prop[j] = price(j,Rop,Omega,Lambda)

    # constraints
    barH=np.zeros(Nt*NS)
    for i in range(Nt):
        barH[i*NS:(i+1)*NS]=dS*dt*np.exp(-rho*T[i])*(pcoef*f(S,Prp[i],T[i])+opcoef*f(S,Prop[i],T[i]))   

    # neumann conditions
    barA=np.zeros((NS,NS))
    barV=1.+delta_R*delta_R*S*(1-S)*dt/(dS*dS)
    barV1 = -delta_R*delta_R*S[1:]*(1.-S[1:])*dt/(2*dS*dS)+kR*(theta_R-S[1:])*dt/(2*dS)
    barV2 = -delta_R*delta_R*S[:-1]*(1.-S[:-1])*dt/(2*dS*dS)-kR*(theta_R-S[:-1])*dt/(2*dS)
    barA.flat[::NS+1] = barV
    barA.flat[1::NS+1] = barV1
    barA.flat[NS::NS+1] = barV2

    A_ub = np.zeros(((Nt-1)*NS,(Nt-1)*NS))
    for i in range(Nt-1):
        A_ub[((i)*NS):((i+1)*NS), ((i)*NS):((i+1)*NS)] = barA
    for i in range(Nt-2):
        A_ub[((i+1)*NS):((i+2)*NS), ((i)*NS):((i+1)*NS)] = -np.diag(np.ones(NS))
    b_ub=np.zeros((Nt-1)*NS)
    b_ub[:NS] = InitialEta

    t0 = time.time()
    res = linprog(-barH[NS:],bsr_matrix(A_ub),b_ub,options={"sparse":True})
    if(res.status): print('OpEntry: '+res.message)

    M1 = res.x
    val = np.dot(barH[NS:],Eta[NS:])
    ob_func = np.dot(barH[NS:],M1)- val
    t1 = time.time()

    return ob_func, val, M1

# %%
Niter=50 # total number of iterations
tol = 1. # convergence achieved if objective function less than tol

# initialisation of omega (gas exit)
Omega=np.zeros(Nt*NC)
Omega[:NC]=InitialOmega

# initialisation of lambda (gas enter)
Lambda=np.zeros(Nt*NC)
Lambda[:NC]=InitialLambda

# initialisation of eta
Eta=np.zeros(Nt*NS)
Eta[:NS] = InitialEta

# peak and peak-off price value (historical)
prphist = np.zeros((Nt,Niter))
prophist = np.zeros((Nt,Niter))

# renewable produice energy
renpen = np.zeros((Nt,Niter))

# conventional capacity
conhist = np.zeros((Nt,Niter))

# electricity produice
penhist = np.zeros((Nt,Niter))

# stock residual peak and off-peak demand value (historical)
RRp = np.zeros((Nt,Niter))
RRop = np.zeros((Nt,Niter))
Pr = np.zeros(Nt)

out1 = "Initial Objectives: Renewable: {:.2f}; Conventional gas exit:  {:.2f}; Conventional gas enter:  {:.2f}; Total: {:.2f}"
out2 = "Weight: {:.4f}; Renewable: {:.2f}; Conventional gas exit:  {:.2f}; Conventional gas enter:  {:.2f}; Total: {:.2f}"

# save objectives
save_ob_G = np.zeros(Niter)
save_ob_G_enter = np.zeros(Niter)
save_ob_R = np.zeros(Niter)

# initialize
ob_G, val_G, Omega1=OptExit_G(Omega,Eta,Lambda)
ob_G_enter, val_G_enter, Lambda1=OptEntry_G(Omega,Eta,Lambda)
ob_R, val_R, Eta1=OptEntry_R(Omega,Eta,Lambda)
print(out1.format(ob_R,ob_G,ob_G_enter,ob_G+ob_G_enter+ob_R))

for i in range(Niter):  

    save_ob_G[i] = ob_G
    save_ob_G_enter[i] = ob_G_enter
    save_ob_R[i] = ob_R

    if ob_R+ob_G+ob_G_enter < tol:
        print('Convergence achieved')
        Niter = i
        break

    print('Iteration ',i)   

    # store intermediate values
    Rp = computeR(Eta,pdemand)
    Rop = computeR(Eta,opdemand)
    
    Prp = np.zeros(Nt)
    Prop = np.zeros(Nt)
    for j in range(Nt):
        Prp[j] = price(j,Rp,Omega,Lambda)
        Prop[j] = price(j,Rop,Omega,Lambda)
        prphist[j,i] = Prp[j]
        prophist[j,i] = Prop[j]

    newEta = np.reshape(Eta,(Nt,NS))
    newOm = np.reshape(Omega,(Nt,NC))
    newLamb = np.reshape(Lambda,(Nt,NC))

    penhist[:,i] = np.sum(newEta,axis=1)*dS
    conhist[:,i] = np.sum(newOm,axis=1)*dC
    renpen[:,i] = np.sum(newEta*S,axis=1)*dS

    # stock residual peak and off-peak demand value (historical)
    RRp[:,i] = Rp
    RRop[:,i] = Rop

    # step size
    weight = 1./(i+1)

    # upgrade the mesures
    Omega[NC:] = (1.-weight)*Omega[NC:]+weight*Omega1
    Lambda[NC:] = (1.-weight)*Lambda[NC:]+weight*Lambda1
    Eta[NS:] = (1.-weight)*Eta[NS:]+weight*Eta1

    # search the solution
    ob_G, val_G, Omega1=OptExit_G(Omega,Eta,Lambda)
    ob_G_enter, val_G_enter, Lambda1=OptEntry_G(Omega,Eta,Lambda)
    ob_R, val_R, Eta1=OptEntry_R(Omega,Eta,Lambda)

    # advancement
    print(out2.format(weight,ob_R,ob_G,ob_G_enter,ob_G+ob_G_enter+ob_R))
# Out:
# Initial Objectives: Renewable: 120770.82; Conventional gas exit:  -0.00; Conventional gas enter:  52820.17; Total: 173590.99
# Iteration  0
# Weight: 1.0000; Renewable: 1188.63; Conventional gas exit:  32165.58; Conventional gas enter:  3133.84; Total: 36488.05
# Iteration  1
# Weight: 0.5000; Renewable: 8588.22; Conventional gas exit:  3871.78; Conventional gas enter:  9382.20; Total: 21842.21
# Iteration  2
# Weight: 0.3333; Renewable: 4424.44; Conventional gas exit:  1423.29; Conventional gas enter:  5377.99; Total: 11225.71
# Iteration  3
# Weight: 0.2500; Renewable: 2693.81; Conventional gas exit:  425.47; Conventional gas enter:  3474.09; Total: 6593.37
# Iteration  4
# Weight: 0.2000; Renewable: 1912.77; Conventional gas exit:  494.92; Conventional gas enter:  2596.12; Total: 5003.81
# Iteration  5
# Weight: 0.1667; Renewable: 1670.25; Conventional gas exit:  625.48; Conventional gas enter:  2380.91; Total: 4676.65
# Iteration  6
# Weight: 0.1429; Renewable: 1276.94; Conventional gas exit:  293.23; Conventional gas enter:  1859.83; Total: 3430.01
# Iteration  7
# Weight: 0.1250; Renewable: 1130.41; Conventional gas exit:  290.89; Conventional gas enter:  1681.65; Total: 3102.96
# Iteration  8
# Weight: 0.1111; Renewable: 938.11; Conventional gas exit:  321.87; Conventional gas enter:  1409.68; Total: 2669.67
# Iteration  9
# Weight: 0.1000; Renewable: 866.85; Conventional gas exit:  213.68; Conventional gas enter:  1320.17; Total: 2400.70
# Iteration  10
# Weight: 0.0909; Renewable: 763.53; Conventional gas exit:  188.64; Conventional gas enter:  1171.67; Total: 2123.84
# Iteration  11
# Weight: 0.0833; Renewable: 690.24; Conventional gas exit:  174.48; Conventional gas enter:  1067.24; Total: 1931.96
# Iteration  12
# Weight: 0.0769; Renewable: 630.94; Conventional gas exit:  161.94; Conventional gas enter:  981.96; Total: 1774.83
# Iteration  13
# Weight: 0.0714; Renewable: 581.09; Conventional gas exit:  150.98; Conventional gas enter:  909.52; Total: 1641.59
# Iteration  14
# Weight: 0.0667; Renewable: 538.57; Conventional gas exit:  141.64; Conventional gas enter:  847.05; Total: 1527.27
# Iteration  15
# Weight: 0.0625; Renewable: 502.73; Conventional gas exit:  132.32; Conventional gas enter:  794.33; Total: 1429.38
# Iteration  16
# Weight: 0.0588; Renewable: 470.45; Conventional gas exit:  125.08; Conventional gas enter:  746.56; Total: 1342.09
# Iteration  17
# Weight: 0.0556; Renewable: 442.78; Conventional gas exit:  117.82; Conventional gas enter:  705.36; Total: 1265.96
# Iteration  18
# Weight: 0.0526; Renewable: 417.47; Conventional gas exit:  112.06; Conventional gas enter:  667.48; Total: 1197.01
# Iteration  19
# Weight: 0.0500; Renewable: 395.56; Conventional gas exit:  106.21; Conventional gas enter:  634.36; Total: 1136.14
# Iteration  20
# Weight: 0.0476; Renewable: 375.31; Conventional gas exit:  101.50; Conventional gas enter:  603.55; Total: 1080.36
# Iteration  21
# Weight: 0.0455; Renewable: 357.47; Conventional gas exit:  96.67; Conventional gas enter:  575.97; Total: 1030.11
# Iteration  22
# Weight: 0.0435; Renewable: 340.78; Conventional gas exit:  92.73; Conventional gas enter:  550.35; Total: 983.87
# Iteration  23
# Weight: 0.0417; Renewable: 326.02; Conventional gas exit:  88.72; Conventional gas enter:  527.56; Total: 942.29
# Iteration  24
# Weight: 0.0400; Renewable: 312.09; Conventional gas exit:  85.34; Conventional gas enter:  505.78; Total: 903.21
# Iteration  25
# Weight: 0.0385; Renewable: 299.66; Conventional gas exit:  81.97; Conventional gas enter:  486.42; Total: 868.05
# Iteration  26
# Weight: 0.0370; Renewable: 287.82; Conventional gas exit:  79.13; Conventional gas enter:  468.02; Total: 834.96
# Iteration  27
# Weight: 0.0357; Renewable: 277.26; Conventional gas exit:  76.18; Conventional gas enter:  451.23; Total: 804.67
# Iteration  28
# Weight: 0.0345; Renewable: 267.07; Conventional gas exit:  73.74; Conventional gas enter:  435.35; Total: 776.16
# Iteration  29
# Weight: 0.0333; Renewable: 257.93; Conventional gas exit:  71.16; Conventional gas enter:  420.93; Total: 750.02
# Iteration  30
# Weight: 0.0323; Renewable: 249.12; Conventional gas exit:  69.06; Conventional gas enter:  407.08; Total: 725.26
# Iteration  31
# Weight: 0.0312; Renewable: 241.14; Conventional gas exit:  66.75; Conventional gas enter:  394.33; Total: 702.23
# Iteration  32
# Weight: 0.0303; Renewable: 233.39; Conventional gas exit:  64.92; Conventional gas enter:  382.16; Total: 680.46
# Iteration  33
# Weight: 0.0294; Renewable: 226.44; Conventional gas exit:  62.83; Conventional gas enter:  371.02; Total: 660.29
# Iteration  34
# Weight: 0.0286; Renewable: 219.66; Conventional gas exit:  61.17; Conventional gas enter:  360.24; Total: 641.07
# Iteration  35
# Weight: 0.0278; Renewable: 213.46; Conventional gas exit:  59.30; Conventional gas enter:  350.23; Total: 622.99
# Iteration  36
# Weight: 0.0270; Renewable: 207.41; Conventional gas exit:  57.80; Conventional gas enter:  340.63; Total: 605.84
# Iteration  37
# Weight: 0.0263; Renewable: 201.86; Conventional gas exit:  56.14; Conventional gas enter:  331.75; Total: 589.75
# Iteration  38
# Weight: 0.0256; Renewable: 196.47; Conventional gas exit:  54.79; Conventional gas enter:  323.11; Total: 574.37
# Iteration  39
# Weight: 0.0250; Renewable: 191.49; Conventional gas exit:  53.30; Conventional gas enter:  315.04; Total: 559.83
# Iteration  40
# Weight: 0.0244; Renewable: 186.61; Conventional gas exit:  52.07; Conventional gas enter:  307.24; Total: 545.92
# Iteration  41
# Weight: 0.0238; Renewable: 182.10; Conventional gas exit:  50.74; Conventional gas enter:  300.00; Total: 532.85
# Iteration  42
# Weight: 0.0233; Renewable: 177.71; Conventional gas exit:  49.60; Conventional gas enter:  292.85; Total: 520.17
# Iteration  43
# Weight: 0.0227; Renewable: 173.62; Conventional gas exit:  48.41; Conventional gas enter:  286.27; Total: 508.30
# Iteration  44
# Weight: 0.0222; Renewable: 169.60; Conventional gas exit:  47.37; Conventional gas enter:  279.82; Total: 496.79
# Iteration  45
# Weight: 0.0217; Renewable: 165.87; Conventional gas exit:  46.29; Conventional gas enter:  273.80; Total: 485.96
# Iteration  46
# Weight: 0.0213; Renewable: 162.16; Conventional gas exit:  45.32; Conventional gas enter:  267.83; Total: 475.32
# Iteration  47
# Weight: 0.0208; Renewable: 158.75; Conventional gas exit:  44.34; Conventional gas enter:  262.32; Total: 465.41
# Iteration  48
# Weight: 0.0204; Renewable: 155.37; Conventional gas exit:  43.45; Conventional gas enter:  256.89; Total: 455.71
# Iteration  49
# Weight: 0.0200; Renewable: 152.24; Conventional gas exit:  42.55; Conventional gas enter:  251.80; Total: 446.60

# %%
# Algorithm convergence illustration
logIter = np.log(range(1,Niter,1))

plt.figure()
plt.plot(logIter, np.log(save_ob_R[1:]), label = "Renewable enter")
plt.plot(logIter, np.log(save_ob_G[1:]), label = "Convention gas exit")
plt.plot(logIter, np.log(save_ob_G_enter[1:]), label = "Convention gas enter")
plt.title("Algorithm convergence")
plt.xlabel('log(iterations)')
plt.ylabel('log(gain increase)')
plt.legend()
plt.show()

# %%
# Electricity demand projections, GW
plt.figure()
plt.plot(2018+T[:60],opdemand[:60],label='Total off-peak demand')
plt.plot(2018+T[:60],pdemand[:60],label='Total peak demand')
plt.title('Electricity demand projections, GW')
plt.legend()
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D # This import has side effects required for the kwarg projection='3d' in the call to fig.add_subplot

fig = plt.figure(figsize=(20,10))

newOm = np.reshape(Omega,(Nt,NC))
ax = fig.add_subplot(121, projection='3d')
XX, YY = np.meshgrid(C, T)
ax.plot_wireframe(XX, YY, newOm)
plt.title('Conventional gas exit')

newLamb = np.reshape(Lambda,(Nt,NC))
ax = fig.add_subplot(132, projection='3d')
XX, YY = np.meshgrid(C, T)
ax.plot_wireframe(XX, YY, newLamb)
plt.title('Conventional gas exit')

newEta = np.reshape(Eta,(Nt,NS))
XX, YY = np.meshgrid(S, T)
ax2 = fig.add_subplot(133, projection='3d')
ax2.plot_wireframe(XX, YY, newEta)
plt.title('Renewable')
# Out:
# Text(0.5, 0.92, 'Renewable')

# %%
plt.figure(figsize=(13,5))

plt.subplot(1,3,1)
plt.plot(Omega)
plt.title('Conventional gas exit')

plt.subplot(1,3,2)
plt.plot(Lambda)
plt.title('Conventional gas enter')

plt.subplot(1,3,3)
plt.plot(Eta)
plt.title('Renewable')
# Out:
# Text(0.5, 1.0, 'Renewable')

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,3,1)
XX, YY = np.meshgrid(C, T)
plt.contourf(YY, XX, newOm)
plt.title('Conventional gas exit')

plt.subplot(1,3,2)
XX, YY = np.meshgrid(C, T)
plt.contourf(YY, XX, newOm)
plt.title('Conventional gas enter')

plt.subplot(1,3,3)
XX, YY = np.meshgrid(S, T)
plt.contourf(YY, XX, newEta)
plt.title('Renewable')
# Out:
# Text(0.5, 1.0, 'Renewable')

# %%
plt.figure(figsize=(14,10))

plt.subplot('231')
plt.plot(2018+T,RRp[:,Niter-1],label='Residual peak demand')
plt.plot(2018+T[:60],pdemand[:60],label='Total peak demand')
plt.plot(2018+T,RRop[:,Niter-1],label='Residual off-peak demand')
plt.plot(2018+T[:60],opdemand[:60],label='Total off-peak demand')
plt.title('Residual and total demand, GW')
plt.legend(loc=2)

plt.subplot('232')
plt.plot(2018+T,prphist[:,Niter-1],label='Peak price')
plt.plot(2018+T,prophist[:,Niter-1],label='Off-peak price')
plt.legend(loc=2)
plt.title('Price, GBP/MWh')

plt.subplot('233')
renhist = np.ones(penhist.shape)*np.sum(BarEta)*dS-penhist
plt.plot(2018+T,renhist[:,Niter-1]+conhist[:,Niter-1],label='Total')
plt.plot(2018+T,renhist[:,Niter-1],label='Renewable')
plt.plot(2018+T,conhist[:,Niter-1],label='Conventional')
plt.legend(loc=2)
plt.title('Installed capacity, GW')

plt.subplot('234')
plt.plot(2018+T,np.sum(BarEta*S)*dS-renpen[:,Niter-1])
plt.title('Renewable production, GW')

#plt.savefig('industry_dynamics_peak_offpeak_baseline.pdf',format='pdf')

plt.subplot('235')
plt.plot(T,conhist[:,-1])
plt.title('Conventional installed capacity')
# Out:
# <ipython-input-21-d026e0ca9f83>:3: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot('231')
# <ipython-input-21-d026e0ca9f83>:11: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot('232')
# <ipython-input-21-d026e0ca9f83>:17: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot('233')
# <ipython-input-21-d026e0ca9f83>:25: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot('234')
# <ipython-input-21-d026e0ca9f83>:31: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot('235')
# Text(0.5, 1.0, 'Conventional installed capacity')
